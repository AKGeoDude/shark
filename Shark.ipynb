# %%
import csv
from pandas import DataFrame, Series
import pandas as pd
import numpy as np

# %%
sharks = pd.read_csv(r'C:\data\shark-attack-incurl.csv', encoding = 'latin1')

# %%
sharks.head()
# Out:
#     Case Number          Date    Year        Type               Country  \
# 0    2017.05.12    2017.05.12  2017.0  Unprovoked  UNITED ARAB EMIRATES
# 1  2017.05.06.R  2017.05.06.R  2017.0    Provoked             AUSTRALIA
# 2    2017.05.06    2017.05.06  2017.0  Unprovoked                MEXICO
# 3    2017.05.03    2017.05.03  2017.0     Invalid                   USA
# 4  2017.04.29.d   29-Apr-2017  2017.0  Unprovoked                   USA
#
#                   Area                       Location  \
# 0            Sharjah,                     Khor Fakkan
# 1           Queensland                          Weipa
# 2  Baja California Sur      Los Arbolitos, Cabo Pulmo
# 3           California    Sunset Beach, Orange County
# 4           California  San Onofre, San Diego County
#
#                       Activity             Name Sex       ...        \
# 0                 Spearfishing    Al Beloushi      M      ...
# 1  Attempting to lasso a shark      Josh Neille    M      ...
# ...

# %%
sharks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order'],
#       dtype='object')

# %%
sharks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6085 entries, 0 to 6084
# Data columns (total 22 columns):
# Case Number               6085 non-null object
# Date                      6085 non-null object
# Year                      6083 non-null float64
# Type                      6082 non-null object
# Country                   6039 non-null object
# Area                      5673 non-null object
# Location                  5574 non-null object
# Activity                  5550 non-null object
# Name                      5879 non-null object
# Sex                       5508 non-null object
# Age                       3368 non-null object
# Injury                    6057 non-null object
# Fatal (Y/N)               6055 non-null object
# Time                      2843 non-null object
# Species                   3092 non-null object
# Investigator or Source    6069 non-null object
# pdf                       6085 non-null object
# href formula              6084 non-null object
# ...

# %%
sharks['Species '].value_counts()
# Out:
# White shark                                                                                                                                                                                164
# Shark involvement not confirmed                                                                                                                                                             81
# Tiger shark                                                                                                                                                                                 71
# Bull shark                                                                                                                                                                                  53
# 6' shark                                                                                                                                                                                    40
# ...
